# %% [markdown]
# # Exercise 01

# %% [markdown]
# This <a href="https://riffspot.com/music/ukulele/mary-had-a-little-lamb/">link</a> shows the music score of a simple song "Mary had a little lamb". The wave file of the melody can be found in "maryLamb.wav". Generate the chords for the melody by following steps.

# %%
import sys
sys.path.append('../ThinkDsp')
import thinkdsp

# %%
melody = thinkdsp.read_wave("maryLamb.wav")
melody.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Step 1: Generate C chord (C-E-G)

# %% [markdown]
# ### 1a: Generate C5 note (523.23 Hz) with the duration 1 second. Assign it to the variable "note_c". Check if it works.

# %%
note_c = thinkdsp.sin_wave(523.25,1)

# %%
note_c.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 1b: Generate E5 note (659.26 Hz) with the duration 1 second. Assign it to the variable "note_e". Check if it works.

# %%
note_e =
# Out:
#   File "<ipython-input-37-55c8635baf92>", line 1
#     note_e =
#              ^
# SyntaxError: invalid syntax

# %%
note_e.make_audio()

# %% [markdown]
# ### 1c: Generate G5 note (783.99 Hz) with the duration 1 second. Assign it to the variable "note_g". Check if it works.

# %%
note_g =

# %%
note_g.make_audio()

# %% [markdown]
# ### 1d: Mix the notes above. Assign the chord to the variable "chord_c". Then normalize and apodize it. Check if it works.

# %%
chord_c = note_c + note_e + note_g
chord_c.normalize()
chord_c.apodize()

# %%
chord_c.make_audio()

# %% [markdown]
# ## Step 2: Repeat Step 1 for G chord (G-B-D). The frequencies of G4, B4, and D5 are 392.00 Hz, 493.88 Hz, and 587.33 Hz respectively. Check if it works.

# %%
note_g = 
note_b = 
note_d = 
chord_g = 
chord_g.normalize()
chord_g.apodize()

# %%
chord_g.make_audio()

# %% [markdown]
# ## Step 3: Combine the chords as the sequence: C-C-G-C-C-C-G-C. Assign the result to the variable "chord". Check if it works.

# %%
chord =

# %%
chord.make_audio()

# %% [markdown]
# ## Step 4: Mix melody to chord. Assign the result to the variable "song". Check if it woks.

# %%
song =

# %%
song.make_audio()
