# %% [markdown]
# # Lab03: Sound generation and processing

# %%
# %matplotlib inline

import sys
sys.path.append('../ThinkDsp')
import thinkdsp
import thinkplot

# %% [markdown]
# ## Generate sound wave from the signals of trigonometric functions

# %%
cos_sig = thinkdsp.CosSignal(freq=440, amp=1, offset=0)
cos_wave = cos_sig.make_wave(duration=1.5, start=0, framerate=11025)
cos_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
cos_wave.plot()

# %%
cos_period = cos_sig.period
cos_segment = cos_wave.segment(start=0, duration=cos_period*6)
cos_segment.plot()

# %%
sin_sig = thinkdsp.SinSignal(freq=880, amp=1, offset=0)
sin_wave = sin_sig.make_wave(duration=1.5, start=0, framerate=11025)
sin_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sin_period = sin_sig.period
sin_segment = sin_wave.segment(start=0, duration=sin_period*6)
sin_segment.plot()

# %% [markdown]
# ## Combine sound waves

# %%
comb_wave = cos_wave | sin_wave
comb_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Combine sound waves with better quality

# %%
cos_wave.apodize()
sin_wave.apodize()
comb_wave = cos_wave | sin_wave
comb_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
cos_segment = cos_wave.segment(start=0, duration=cos_period*6)
cos_segment.plot()

# %% [markdown]
# ## Mix sound waves

# %%
cos_sig2 = thinkdsp.CosSignal(freq=880, amp=1, offset=0)
cos_wave2 = cos_sig2.make_wave(duration=1.5, start=0, framerate=11025)

mix_wave = cos_wave + cos_wave2
mix_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mix_segment = mix_wave.segment(start=1, duration=cos_period*6)
mix_segment.plot()

# %% [markdown]
# ## Mix sound waves with better quality

# %%
mix_wave = cos_wave + cos_wave2
mix_wave.normalize()
mix_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mix_segment = mix_wave.segment(start=1, duration=cos_period*6)
mix_segment.plot()

# %% [markdown]
# ## Spectrum of sound wave

# %%
sp = mix_wave.make_spectrum()
sp.plot(high=2000)

# %% [markdown]
# ## Generate sound wave from the the square signal

# %%
square_sig = thinkdsp.SquareSignal(freq=100, amp=1, offset=0)
square_wave = square_sig.make_wave(duration=1.5, start=0, framerate=11025)
square_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sq_period = square_sig.period
sq_segment = square_wave.segment(start=0, duration=sq_period*6)
sq_segment.plot()

# %%
sp = square_wave.make_spectrum()
sp.plot()

# %% [markdown]
# ## Low pass filter

# %%
sp.low_pass(1000)
sp.plot()

# %%
square_wave_low_pass = sp.make_wave()
square_wave_low_pass.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sq_segment = square_wave_low_pass.segment(start=0, duration=sq_period*6)
sq_segment.plot()

# %% [markdown]
# ## High pass filter

# %%
sp = square_wave.make_spectrum()
sp.high_pass(1000)
sp.plot()

# %%
square_wave_high_pass = sp.make_wave()
square_wave_high_pass.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sq_segment = square_wave_high_pass.segment(start=0, duration=sq_period*6)
sq_segment.plot()

# %% [markdown]
# ## Generate sound wave from the triangle signal

# %%
triangle_sig = thinkdsp.TriangleSignal(freq=200, amp=1, offset=0)
triangle_wave = triangle_sig.make_wave(duration=1.5, start=0, framerate=11025)
triangle_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tri_period = triangle_sig.period
tri_segment = triangle_wave.segment(start=0, duration=sq_period*6)
tri_segment.plot()

# %%
sp = triangle_wave.make_spectrum()
sp.plot(high=3000)
